# %%
import boto3, json, os, glob, cv2
import numpy as np
import math
import re
import time

# %% [markdown]
# ### Batchify
#
# Goal here is to import the individual arrays from the videos and convert them to one large array of size `batch_size x 28`. There are a few ways to approach this.
#
# 1. Choose a predetermined number of frames and either a) pad the remainder of the frames to reach the predetermined number at the end of the video, b) delete the remainder, c) pad if the remainder is at least half of the predetermined number, and delete if the remainder is less than half, d) start the next video where the previous one left off (maybe also including a token to indicate the video is changing)
#
# 2. Determine the largest video we have and pad all other videos to reach that length.
#
# I think #1d is a bad idea. For now (in part because I'm using a smaller test dataset) I'm going with #1c, but we can play with this to see how it affects accuracy, if at all. Ultimately, we may decide to implement #2.

# %%
#Initialize s3 interface.
s3 = boto3.resource('s3')
# Select our bucket - the OpenPose files for the YouTube videos are in dancegan-yt-vids.
# dancegan_yt_vids = s3.Bucket('dancegan-yt-vids')

from s3fs.core import S3FileSystem
s3fs = S3FileSystem()

# %% [markdown]
# We will ultimately have three numpy arrays saved in the `Models` directory:
#
# 1. YouTube videos from Everybody Dance Now: `vids_yt_all.npy`; saved already in `Models` directory
# 2. YouTube videos from vid2vid: `vids_v2v_all.npy`; individual arrays (300-1888) are now in `Models/DataPreprocessing/NumpyPoses`; individual arrays for (0-299) are on s3 in "`vid-numpy`" bucket with prefix `/vid2vid-poses/`
# 3. numpy arrays stitched together from Dancing to Music: `vids_d2m_all.npy`; are on s3 in "`dancegan-d2m`" bucket with prefix `/output/ballet/-0APC9DynPE/`, eg, there are three directories: `ballet`, `hiphop`, `zumba` and each of those includes a unique directory (eg, `-0APC9DynPE`) for individual videos within it; I will save these as three separate numpy files: `vids_d2m_ballet.npy`, `vids_d2m_hiphop.npy`, `vids_d2m_zumba.npy` and concatenate them to make `vids_d2m_all.npy`.

# %% [markdown]
# ### 1. vid2vid arrays

# %%
# First, get the 300 from s3.
def single_vid_batchify_s3(video,length):
    '''Takes the video number in string format, gets the 2d numpy array of 
    keypoints and returns a 3d numpy array of mini-batches 
    of passed-in length. Remainders less than half of the length are deleted.
    Remainders of at least half of the length are padded.'''
    # Get the numpy array for the video from s3.
    key = f'vid2vid-poses/poses{video}.npy'
    bucket = 'vid-numpy'
#     key = f'numpy-arrays/poses{video}.npy'
#     bucket = 'dancegan-yt-vids'
    poses = np.load(s3fs.open(f'{bucket}/{key}'))
#     poses = np.load(f'poses{video}.npy')
    # Reshape to 3d array.
    # Make sure the number of frames dimension is divisible by the mini-batch length.
    n_padded_frames = length - (poses.shape[0] % length)
    # Create padded frames to fill the last batch.
    # What number do we want to use for the padding? Will zero work?
    # Using a variable here (instead of np.zeros) so we can easily change it.
    fill_value = 0
    padded_frames = np.full((n_padded_frames,28),fill_value)
    # Append the padded_frames to the end of the original array.
    padded_poses = np.append(poses,padded_frames, axis=0)
    # Now reshape into batches of batch_size frames.
    n_all_frames = padded_poses.shape[0]
    padded_poses = padded_poses.reshape(int(n_all_frames/length),length,28)
    
    return padded_poses

# %%
mini_batch_vids_v2v_s3 = {}
length = 300
for i in range(0,300):
    video_number = f'{i:05d}'
    print(f'Creating mini-batch for video-{video_number}.')
    mini_batch_vids_v2v_s3[i] = single_vid_batchify_s3(video_number,length)
    print('-'*72)
# Out:
# Creating mini-batch for video-00000.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00001.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00002.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00003.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00004.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00005.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00006.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00007.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00008.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00009.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00010.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00011.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00012.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00013.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00014.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00015.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00016.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00017.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00018.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00019.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00020.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00021.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00022.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00023.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00024.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00025.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00026.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00027.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00028.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00029.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00030.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00031.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00032.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00033.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00034.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00035.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00036.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00037.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00038.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00039.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00040.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00041.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00042.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00043.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00044.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00045.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00046.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00047.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00048.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00049.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00050.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00051.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00052.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00053.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00054.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00055.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00056.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00057.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00058.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00059.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00060.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00061.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00062.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00063.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00064.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00065.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00066.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00067.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00068.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00069.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00070.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00071.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00072.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00073.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00074.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00075.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00076.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00077.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00078.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00079.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00080.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00081.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00082.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00083.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00084.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00085.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00086.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00087.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00088.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00089.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00090.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00091.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00092.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00093.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00094.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00095.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00096.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00097.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00098.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00099.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00100.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00101.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00102.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00103.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00104.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00105.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00106.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00107.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00108.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00109.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00110.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00111.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00112.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00113.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00114.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00115.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00116.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00117.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00118.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00119.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00120.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00121.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00122.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00123.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00124.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00125.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00126.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00127.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00128.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00129.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00130.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00131.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00132.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00133.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00134.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00135.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00136.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00137.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00138.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00139.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00140.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00141.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00142.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00143.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00144.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00145.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00146.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00147.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00148.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00149.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00150.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00151.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00152.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00153.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00154.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00155.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00156.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00157.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00158.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00159.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00160.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00161.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00162.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00163.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00164.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00165.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00166.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00167.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00168.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00169.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00170.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00171.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00172.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00173.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00174.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00175.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00176.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00177.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00178.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00179.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00180.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00181.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00182.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00183.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00184.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00185.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00186.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00187.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00188.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00189.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00190.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00191.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00192.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00193.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00194.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00195.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00196.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00197.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00198.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00199.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00200.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00201.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00202.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00203.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00204.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00205.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00206.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00207.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00208.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00209.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00210.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00211.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00212.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00213.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00214.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00215.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00216.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00217.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00218.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00219.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00220.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00221.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00222.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00223.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00224.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00225.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00226.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00227.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00228.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00229.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00230.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00231.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00232.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00233.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00234.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00235.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00236.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00237.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00238.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00239.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00240.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00241.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00242.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00243.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00244.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00245.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00246.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00247.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00248.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00249.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00250.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00251.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00252.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00253.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00254.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00255.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00256.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00257.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00258.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00259.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00260.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00261.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00262.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00263.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00264.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00265.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00266.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00267.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00268.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00269.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00270.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00271.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00272.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00273.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00274.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00275.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00276.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00277.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00278.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00279.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00280.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00281.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00282.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00283.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00284.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00285.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00286.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00287.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00288.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00289.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00290.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00291.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00292.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00293.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00294.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00295.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00296.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00297.
# ------------------------------------------------------------------------
# Creating mini-batch for video-00298.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-b57d62045b1b> in <module>
#       4     video_number = f'{i:05d}'
#       5     print(f'Creating mini-batch for video-{video_number}.')
# ----> 6     mini_batch_vids_v2v_s3[i] = single_vid_batchify_s3(video_number,length)
#       7     print('-'*72)
#
# <ipython-input-6-c49d5d8a0a08> in single_vid_batchify_s3(video, length)
#      10 #     key = f'numpy-arrays/poses{video}.npy'
#      11 #     bucket = 'dancegan-yt-vids'
# ---> 12     poses = np.load(s3fs.open(f'{bucket}/{key}'))
#      13 #     poses = np.load(f'poses{video}.npy')
#      14     # Reshape to 3d array.
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     772                 autocommit=ac,
#     773                 cache_options=cache_options,
# --> 774                 **kwargs
#     775             )
#     776             if not ac:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     313                       version_id=version_id, fill_cache=fill_cache,
#     314                       s3_additional_kwargs=kw, cache_type=cache_type,
# --> 315                       autocommit=autocommit, requester_pays=requester_pays)
#     316
#     317     def _lsdir(self, path, refresh=False, max_items=None):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#     955         self.req_kw = {'RequestPayer': 'requester'} if requester_pays else {}
#     956         super().__init__(s3, path, mode, block_size, autocommit=autocommit,
# --> 957                          cache_type=cache_type)
#     958         self.s3 = self.fs  # compatibility
#     959         if self.writable():
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1054         if mode == "rb":
#    1055             if not hasattr(self, "details"):
# -> 1056                 self.details = fs.info(path)
#    1057             self.size = self.details["size"]
#    1058             self.cache = caches[cache_type](
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/s3fs/core.py in info(self, path, version_id)
#     484             except ParamValidationError as e:
#     485                 raise ValueError('Failed to head path %r: %s' % (path, e))
# --> 486         return super().info(path)
#     487
#     488     def isdir(self, path):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/fsspec/spec.py in info(self, path, **kwargs)
#     550             return {"name": path, "size": 0, "type": "directory"}
#     551         else:
# --> 552             raise FileNotFoundError(path)
#     553
#     554     def checksum(self, path):
#
# FileNotFoundError: vid-numpy/vid2vid-poses/poses00298.npy

# %%
# Next, get 301-1888 in Models/DataPreprocessing/NumpyPoses.
def single_vid_batchify_local(video,length):
    '''Takes the video number in string format, gets the 2d numpy array of 
    keypoints and returns a 3d numpy array of mini-batches 
    of passed-in length. Remainders less than half of the length are deleted.
    Remainders of at least half of the length are padded.'''
    # Get the numpy array for the video.
    filename = f'poses{video}.npy'
    poses = np.load(f'./NumpyPoses/{filename}')
    # Reshape to 3d array.
    # Make sure the number of frames dimension is divisible by the mini-batch length.
    n_padded_frames = length - (poses.shape[0] % length)
    # Create padded frames to fill the last batch.
    # What number do we want to use for the padding? Will zero work?
    # Using a variable here (instead of np.zeros) so we can easily change it.
    fill_value = 0
    padded_frames = np.full((n_padded_frames,28),fill_value)
    # Append the padded_frames to the end of the original array.
    padded_poses = np.append(poses,padded_frames, axis=0)
    # Now reshape into batches of batch_size frames.
    n_all_frames = padded_poses.shape[0]
    padded_poses = padded_poses.reshape(int(n_all_frames/length),length,28)
    
    return padded_poses

# %%
length = 300
for i in range(301,1888):
    video_number = f'{i:05d}'
    print(f'Creating mini-batch for video-{video_number}.')
    mini_batch_vids_v2v_s3[i] = single_vid_batchify_s3(video_number,length)
    print('-'*72)
# Out:
# Creating mini-batch for video-01888.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-9f59adf8b2ac> in <module>
#       3     video_number = f'{i:05d}'
#       4     print(f'Creating mini-batch for video-{video_number}.')
# ----> 5     mini_batch_vids_v2v_s3[i] = single_vid_batchify_s3(video_number,length)
#       6     print('-'*72)
#
# <ipython-input-6-c49d5d8a0a08> in single_vid_batchify_s3(video, length)
#      10 #     key = f'numpy-arrays/poses{video}.npy'
#      11 #     bucket = 'dancegan-yt-vids'
# ---> 12     poses = np.load(s3fs.open(f'{bucket}/{key}'))
#      13 #     poses = np.load(f'poses{video}.npy')
#      14     # Reshape to 3d array.
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     772                 autocommit=ac,
#     773                 cache_options=cache_options,
# --> 774                 **kwargs
#     775             )
#     776             if not ac:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     313                       version_id=version_id, fill_cache=fill_cache,
#     314                       s3_additional_kwargs=kw, cache_type=cache_type,
# --> 315                       autocommit=autocommit, requester_pays=requester_pays)
#     316
#     317     def _lsdir(self, path, refresh=False, max_items=None):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#     955         self.req_kw = {'RequestPayer': 'requester'} if requester_pays else {}
#     956         super().__init__(s3, path, mode, block_size, autocommit=autocommit,
# --> 957                          cache_type=cache_type)
#     958         self.s3 = self.fs  # compatibility
#     959         if self.writable():
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1054         if mode == "rb":
#    1055             if not hasattr(self, "details"):
# -> 1056                 self.details = fs.info(path)
#    1057             self.size = self.details["size"]
#    1058             self.cache = caches[cache_type](
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/s3fs/core.py in info(self, path, version_id)
#     484             except ParamValidationError as e:
#     485                 raise ValueError('Failed to head path %r: %s' % (path, e))
# --> 486         return super().info(path)
#     487
#     488     def isdir(self, path):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/fsspec/spec.py in info(self, path, **kwargs)
#     550             return {"name": path, "size": 0, "type": "directory"}
#     551         else:
# --> 552             raise FileNotFoundError(path)
#     553
#     554     def checksum(self, path):
#
# FileNotFoundError: vid-numpy/vid2vid-poses/poses01888.npy

# %%
np.save('mini_batch_vids_v2v_s3.npy',mini_batch_vids_v2v_s3)

# %%
type(mini_batch_vids_v2v_s3)
# Out:
# dict

# %%
mini_batch_vids_v2v = np.load('mini_batch_vids_v2v_s3.npy', allow_pickle=True)

# %%
mini_batch_vids_v2v[()][0].shape
# Out:
# (11, 300, 28)

# %%
len(mini_batch_vids_v2v[()])
# Out:
# 1874

# %%
vids_v2v_all = np.empty((0,300,28))

# %%
for key in mini_batch_vids_v2v[()]:
    vids_v2v_all = np.append(vids_v2v_all,mini_batch_vids_v2v[()][key], axis=0)

# %%
vids_v2v_all.shape
# Out:
# (38279, 300, 28)

# %%
np.save('../vids_v2v_all.npy',vids_v2v_all)

# %% [markdown]
# ### 2. D2M arrays

# %% [markdown]
# Goal is to save as `vids_d2m_all.npy` in the `Models/` directory; are on s3 in "`dancegan-d2m`" bucket with prefix `/output/ballet/-0APC9DynPE/`, eg, there are three directories: `ballet`, `hiphop`, `zumba` and each of those includes a unique directory (eg, `-0APC9DynPE`) for individual videos within it; I will save these as three separate numpy files: `vids_d2m_ballet.npy`, `vids_d2m_hiphop.npy`, `vids_d2m_zumba.npy` and concatenate them to make `vids_d2m_all.npy`.
